# %%
#connect to the server

import datajoint as dj
dj.config.load('/Users/neurozmar/Secrets/dj_local_conf_NDNF_behavior_HUN-REN_cloud.json')#dj_local_conf_NDNF_behavior_KOKI.json #dj_local_conf_NDNF_behavior_HUN-REN_cloud
dj.conn() 
import matplotlib.pyplot as plt
# Out:
# [2026-07-22 19:16:16,314][INFO]: DataJoint is configured from /Users/neurozmar/Secrets/dj_local_conf_NDNF_behavior_HUN-REN_cloud.json

# %%
# take a look at the lab schema
schema = dj.Schema('pipeline_lab')
d = dj.Diagram(schema)
fig = plt.figure(figsize = (30, 30))
d.draw()

# %%
# take a look at the experiment schema
schema = dj.Schema('pipeline_experiment')
d = dj.Diagram(schema)
fig = plt.figure(figsize = (30, 30))
d.draw()
